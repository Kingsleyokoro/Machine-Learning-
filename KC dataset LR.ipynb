# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('kc_house_data.csv')
df.columns
cols=df.columns.to_list()
cols
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df = df[['id',
 'date',
 'bedrooms',
 'bathrooms',
 'sqft_living',
 'sqft_lot',
 'floors',
 'waterfront',
 'view',
 'condition',
 'grade',
 'sqft_above',
 'sqft_basement',
 'yr_built',
 'yr_renovated',
 'zipcode',
 'lat',
 'long',
 'sqft_living15',
 'sqft_lot15','price']]

# %%
df.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013T000000         3       1.00         1180      5650
# 1  6414100192  20141209T000000         3       2.25         2570      7242
# 2  5631500400  20150225T000000         2       1.00          770     10000
# 3  2487200875  20141209T000000         4       3.00         1960      5000
# 4  1954400510  20150218T000000         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 0     1.0           0     0          3  ...        1180              0
# 1     2.0           0     0          3  ...        2170            400
# 2     1.0           0     0          3  ...         770              0
# 3     1.0           0     0          5  ...        1050            910
# 4     1.0           0     0          3  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# price            21613 non-null float64
# ...

# %%
0 in df['bedrooms']
# Out:
# True

# %%
0 in df['bathrooms'].unique()
# Out:
# True

# %%
df= df[df['bathrooms']!=0] #it is not realistic to have zero bathrooms in a house . Hence drop all rows with zero bathrooms

# %%
df.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013T000000         3       1.00         1180      5650
# 1  6414100192  20141209T000000         3       2.25         2570      7242
# 2  5631500400  20150225T000000         2       1.00          770     10000
# 3  2487200875  20141209T000000         4       3.00         1960      5000
# 4  1954400510  20150218T000000         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 0     1.0           0     0          3  ...        1180              0
# 1     2.0           0     0          3  ...        2170            400
# 2     1.0           0     0          3  ...         770              0
# 3     1.0           0     0          5  ...        1050            910
# 4     1.0           0     0          3  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21603 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21603 non-null int64
# date             21603 non-null object
# bedrooms         21603 non-null int64
# bathrooms        21603 non-null float64
# sqft_living      21603 non-null int64
# sqft_lot         21603 non-null int64
# floors           21603 non-null float64
# waterfront       21603 non-null int64
# view             21603 non-null int64
# condition        21603 non-null int64
# grade            21603 non-null int64
# sqft_above       21603 non-null int64
# sqft_basement    21603 non-null int64
# yr_built         21603 non-null int64
# yr_renovated     21603 non-null int64
# zipcode          21603 non-null int64
# lat              21603 non-null float64
# long             21603 non-null float64
# sqft_living15    21603 non-null int64
# sqft_lot15       21603 non-null int64
# price            21603 non-null float64
# ...

# %%
df.corr()
# Out:
#                      id  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# id             1.000000  0.001451   0.005234    -0.012200 -0.132070  0.018460
# bedrooms       0.001451  1.000000   0.513909     0.577904  0.031779  0.176933
# bathrooms      0.005234  0.513909   1.000000     0.755789  0.087932  0.502462
# sqft_living   -0.012200  0.577904   0.755789     1.000000  0.172955  0.353824
# sqft_lot      -0.132070  0.031779   0.087932     0.172955  1.000000 -0.005071
# floors         0.018460  0.176933   0.502462     0.353824 -0.005071  1.000000
# waterfront    -0.002720 -0.006733   0.063744     0.103856  0.021605  0.023733
# view           0.011560  0.080168   0.188390     0.284726  0.074807  0.028752
# condition     -0.023801  0.027337  -0.126263    -0.059145 -0.008914 -0.264005
# grade          0.008246  0.357022   0.665887     0.762857  0.113973  0.458605
# sqft_above    -0.010785  0.479032   0.686735     0.876478  0.183659  0.523864
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)

# %%
df['bathrooms'].unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        3.5 , 0.75, 4.75, 5.  , 4.25, 3.75, 1.25, 5.25, 6.  , 0.5 , 5.5 ,
#        6.75, 5.75, 8.  , 7.5 , 7.75, 6.25, 6.5 ])

# %%
df['yr_renovated'].unique()
# Out:
# array([   0, 1991, 2002, 2010, 1999, 1992, 2013, 1994, 1978, 2005, 2008,
#        2003, 1984, 1954, 2014, 2011, 1974, 1983, 1945, 1990, 1988, 1957,
#        1977, 1981, 1995, 2000, 1998, 1970, 1989, 2004, 1986, 2009, 2007,
#        1987, 1973, 2006, 1985, 2001, 1980, 1971, 1979, 1997, 1950, 1969,
#        1948, 2015, 1968, 2012, 1963, 1951, 1993, 1962, 1996, 1972, 1953,
#        1955, 1982, 1956, 1940, 1976, 1946, 1975, 1958, 1964, 1959, 1960,
#        1967, 1965, 1934, 1944], dtype=int64)

# %%
df_drop=df.drop(['id','lat','long','date','yr_renovated','waterfront','view','sqft_basement','condition'],axis=1)

# %%
df_drop.head()
df_1 = df_drop

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21603 entries, 0 to 21612
# Data columns (total 12 columns):
# bedrooms         21603 non-null int64
# bathrooms        21603 non-null float64
# sqft_living      21603 non-null int64
# sqft_lot         21603 non-null int64
# floors           21603 non-null float64
# grade            21603 non-null int64
# sqft_above       21603 non-null int64
# yr_built         21603 non-null int64
# zipcode          21603 non-null int64
# sqft_living15    21603 non-null int64
# sqft_lot15       21603 non-null int64
# price            21603 non-null float64
# dtypes: float64(3), int64(9)
# memory usage: 2.1 MB

# %%
df_1['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 0        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
sns.countplot(df_1['bedrooms'])

# %%
df_1 = df_1[df_1['bedrooms']<=10] #dropping all rows with more than 10 bedrooms!

# %%
df_1.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  grade  sqft_above  \
# 0         3       1.00         1180      5650     1.0      7        1180
# 1         3       2.25         2570      7242     2.0      7        2170
# 2         2       1.00          770     10000     1.0      6         770
# 3         4       3.00         1960      5000     1.0      7        1050
# 4         3       2.00         1680      8080     1.0      8        1680
#
#    yr_built  zipcode  sqft_living15  sqft_lot15     price
# 0      1955    98178           1340        5650  221900.0
# 1      1951    98125           1690        7639  538000.0
# 2      1933    98028           2720        8062  180000.0
# 3      1965    98136           1360        5000  604000.0
# 4      1987    98074           1800        7503  510000.0

# %%
df_1.corr()
# Out:
#                bedrooms  bathrooms  sqft_living  sqft_lot    floors     grade  \
# bedrooms       1.000000   0.527643     0.593406  0.033039  0.182591  0.367434
# bathrooms      0.527643   1.000000     0.755774  0.087943  0.502430  0.665938
# sqft_living    0.593406   0.755774     1.000000  0.172967  0.353784  0.762903
# sqft_lot       0.033039   0.087943     0.172967  1.000000 -0.005070  0.113963
# floors         0.182591   0.502430     0.353784 -0.005070  1.000000  0.458630
# grade          0.367434   0.665938     0.762903  0.113963  0.458630  1.000000
# sqft_above     0.492660   0.686722     0.876476  0.183665  0.523830  0.756149
# yr_built       0.160708   0.507156     0.318052  0.053098  0.489321  0.447443
# zipcode       -0.158709  -0.204880    -0.199845 -0.129539 -0.059510 -0.185744
# sqft_living15  0.404878   0.569851     0.756342  0.144656  0.279906  0.713520
# sqft_lot15     0.030847   0.087556     0.183446  0.718544 -0.011105  0.119682
# ...

# %%
df_1.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'grade',
#        'sqft_above', 'yr_built', 'zipcode', 'sqft_living15', 'sqft_lot15',
#        'price'],
#       dtype='object')

# %%
X = df_1.iloc[:,:len(df_1.columns)-1].values
y = df_1.iloc[:,-1].values

# %%
#x = data.loc[:, data.columns != 'price'] ----> anther way do seperate the target
#column from the feature.

# %%
y= y.reshape(-1, 1)

# %%
X.shape
# Out:
# (21601, 11)

# %%
y.shape
# Out:
# (21601, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
pred = lm.predict(X_test)

# %%
plt.scatter(y_test,pred)

# %%
lr_score = lm.score(X_test,y_test)
print(lr_score)
# Out:
# 0.6132904825576759

# %%
plt.hist((y_test-pred),bins=50,color='r')
# Out:
# (array([3.000e+00, 3.000e+00, 7.000e+00, 1.300e+01, 6.700e+01, 1.610e+02,
#         4.890e+02, 1.069e+03, 1.713e+03, 1.579e+03, 8.340e+02, 2.620e+02,
#         9.900e+01, 5.100e+01, 3.800e+01, 2.400e+01, 1.500e+01, 1.800e+01,
#         5.000e+00, 9.000e+00, 2.000e+00, 4.000e+00, 2.000e+00, 1.000e+00,
#         1.000e+00, 5.000e+00, 2.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([-960287.03450607, -852630.59095882, -744974.14741157,
#         -637317.70386432, -529661.26031707, -422004.81676983,
#         -314348.37322258, -206691.92967533,  -99035.48612808,
#            8620.95741917,  116277.40096642,  223933.84451367,
#          331590.28806092,  439246.73160817,  546903.17515542,
# ...

# %%
lm.coef_
# Out:
# array([[-5.56892268e+04,  5.60981446e+04,  2.07016476e+02,
#         -6.27579255e-02,  2.36040290e+04,  1.20891683e+05,
#         -3.00959503e+01, -4.00372469e+03,  7.52027013e+01,
#          3.06383889e+01, -4.17524811e-01]])

# %%
from sklearn.metrics import r2_score
print('R squared =', r2_score(y_test, pred))
# Out:
# R squared = 0.6132904825576759

# %%
from sklearn.ensemble import RandomForestRegressor
rand_regr = RandomForestRegressor(n_estimators=400,random_state=0)

rand_regr.fit(X_train, y_train)

random=rand_regr.score(X_test,y_test)
predictions = rand_regr.predict(X_test)

# %%
for i in range(50,401,50):
    rand_regr1 = RandomForestRegressor(n_estimators=i,random_state=0)

    rand_regr1.fit(X_train, y_train)
    predictions = rand_regr1.predict(X_test)
    print(rand_regr1.score(X_test,y_test))
# Out:
# 0.7794860184153856
# 0.7785142273315491
# 0.7786465284278932
# 0.7811347040057194
# 0.7822909292705117
# 0.7832579523296985
# 0.7843065998026245
# 0.7843033602452345

# %%
print('R squared using Random Forest Regressor =', r2_score(y_test, predictions))
# Out:
# R squared using Random Forest Regressor = 0.7843033602452345

# %%
print(random)
# Out:
# 0.7843033602452345

# %%
from sklearn.tree  import DecisionTreeRegressor
decision=DecisionTreeRegressor()

decision.fit(X_train, y_train)

decc=decision.score(X_test,y_test)
decpredict = decision.predict(X_test)

# %%
print('R squared using Decision Tree Regressor =', r2_score(y_test, decpredict))
# Out:
# R squared using Decision Tree Regressor = 0.637505598560242

# %%
from sklearn.ensemble import GradientBoostingRegressor
est=GradientBoostingRegressor(n_estimators=400, max_depth=5, loss='ls',min_samples_split=2,learning_rate=0.1).fit(X_train, y_train)

gradient=est.score(X_test,y_test)

pred1 = est.predict(X_test)

# %%
gradient
# Out:
# 0.8344332585394078

# %%
from sklearn.svm import SVR

# %%
model_svm = SVR().fit(X_train,y_train)

# %%
y_pred_svm = model_svm.predict(X_test)

# %%
SVM_r = model_svm.score(X_test,y_test)
SVM_r
# Out:
# -0.060550260835046554

# %%
model_comparison = pd.DataFrame({'Model' :['GBR','DTR','RFR','LR','SVM'],'Model Performance by r2': [gradient,decc,random,lr_score,SVM_r]})
model_comparison.sort_values(by='Model Performance by r2',ascending=False)
# Out:
#   Model  Model Performance by r2
# 0   GBR                 0.834433
# 2   RFR                 0.784303
# 1   DTR                 0.637506
# 3    LR                 0.613290
# 4   SVM                -0.060550
